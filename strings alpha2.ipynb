# %%
my_string="my country Pakistan"
my_string[0:1]
# Out:
# 'm'

# %%
my_string="my country Pakistan"
my_string[0:6]
# Out:
# 'my cou'

# %%
my_string="my country Pakistan"
my_string[0:10]
# Out:
# 'my country'

# %%
my_string="my country Pakistan"
my_string[0:17]
# Out:
# 'my country Pakist'

# %%
my_string="my country Pakistan"
my_string[0:20]
# Out:
# 'my country Pakistan'

# %%
my_string="my country Pakistan"
my_string[0:-3]
# Out:
# 'my country Pakis'

# %%
my_string="my country Pakistan"
my_string[0:-7]
# Out:
# 'my country P'

# %%
my_string="my country Pakistan"
my_string[0:-14]
# Out:
# 'my co'

# %%
my_string="my country Pakistan"
my_string[0:-19]
# Out:
# ''

# %%
eman_string="She live in Karachi"
print(eman_string[4])
# Out:
# l

# %%
eman_string="She live in Karachi"
print(eman_string[3])

# %%
eman_string="She live in Karachi"
print(eman_string[2])
# Out:
# e

# %%
eman_string="She live in Karachi"
print(eman_string[5])
# Out:
# i

# %%
eman_string="She live in Karachi"
print(eman_string[10])
# Out:
# n

# %%
eman_string="She live in Karachi"
print(eman_string[13])
# Out:
# a

# %%
my_string= "I like %s" % "Python"
my_string
# Out:
# 'I like Python'

# %%
my_variable=" I like %s" %"to go to seaview"
my_variable
# Out:
# ' I like to go to seaview'

# %%
favorite= "reading book"
new_string= "I like %s" % favorite
new_string
# Out:
# 'I like reading book'

# %%
value= "cake"
my_string= "I like %s and %s " %("Jupiter notebook ", value)
my_string
# Out:
# 'I like Jupiter notebook  and cake '
