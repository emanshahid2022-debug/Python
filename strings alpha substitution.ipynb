# %%
print("%(lang)s is fun!"% {"lang":"Python"})
# Out:
# Python is fun!

# %%
print("%(value)s is best teacher!"% {"value":"My teacher"})
# Out:
# My teacher is best teacher!

# %%
print("%(name)s is a student of Al Nafi International college."% {"name":"Eman"})
# Out:
# Eman is a student of Al Nafi International college.

# %%
print("%(variable)s is a highest number?"% {"variable" : "99999999"})
# Out:
# 99999999 is a highest number?

# %%
print("%(x)i+%(y)i+%(z)i=%(a)i" %{"x":10,"y":50,"z":20,"a":80})
# Out:
# 10+50+20=80

# %%
print("%(d)i*%(e)i*%(f)i=%(z)i" %{"d":5,"e":2,"f":5,"z":50 })
# Out:
# 5*2*5=50

# %%
print("%(a)i+%(b)i=%(x)i" %{"a":5, "b":20, "x":25})
# Out:
# 5+20=25

# %%
"Programming is as simple as {0},{1},{2}" .format("a","b","c")
# Out:
# 'Programming is as simple as a,b,c'

# %%
"Python is like doing and learning {0},{1},{2}". format("strings","for-loops","while-loops")
# Out:
# 'Python is like doing and learning strings,for-loops,while-loops'

# %%
"Eman loves the subjects like {0},{1},{2},{3}". format("Math","Biology","Englsih","Urdu")
# Out:
# 'Eman loves the subjects like Math,Biology,Englsih,Urdu'
