# %%
my_string="this is my string"
print(my_string)
# Out:
# this is my string

# %%
eman_string='''I am a foody girl'''
print(eman_string)
# Out:
# I am a foody girl

# %%
Eman_Fatima='I love Biryani'
print(Eman_Fatima)
# Out:
# I love Biryani

# %%
other_string='the word "python" refers to another word'
print(other_string)
# Out:
# the word "python" refers to another word

# %%
other_string='the word "python" refers to snake'
print(other_string)
# Out:
# the word "python" refers to snake

# %%
triple_string="""here another way to "embeded" quotes in a string"""
print(triple_string)
# Out:
# here another way to "embeded" quotes in a string

# %%
my_number=12345678910
print(my_number)
# Out:
# 12345678910

# %%
string_one=' Eman is a '
string_two='good'
string_three=' girl'
string_four=string_one+string_two+string_three
print(string_four)
# Out:
#  Eman is a good girl

# %%
eman_string="She wants to be a kid again"
eman_string.upper()
# Out:
# 'SHE WANTS TO BE A KID AGAIN'

# %%
eman_string="She wants to be a kid again"
eman_string.lower()
# Out:
# 'she wants to be a kid again'

# %%
dir(my_string)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
help(my_string.upper)
# Out:
# Help on built-in function upper:
#
# upper() method of builtins.str instance
#     Return a copy of the string converted to uppercase.

# %%
help(my_string.lower)
# Out:
# Help on built-in function lower:
#
# lower() method of builtins.str instance
#     Return a copy of the string converted to lowercase.

# %%
help(my_string.translate)
# Out:
# Help on built-in function translate:
#
# translate(table, /) method of builtins.str instance
#     Replace each character in the string using the given translation table.
#
#       table
#         Translation table, which must be a mapping of Unicode ordinals to
#         Unicode ordinals, strings, or None.
#
#     The table must implement lookup/indexing via __getitem__, for instance a
#     dictionary or list.  If this operation raises LookupError, the character is
#     left untouched.  Characters mapped to None are deleted.

# %%
help(my_string.split)
# Out:
# Help on built-in function split:
#
# split(sep=None, maxsplit=-1) method of builtins.str instance
#     Return a list of the substrings in the string, using sep as the separator string.
#
#       sep
#         The separator used to split the string.
#
#         When set to None (the default value), will split on any whitespace
#         character (including \n \r \t \f and spaces) and will discard
#         empty strings from the result.
#       maxsplit
#         Maximum number of splits.
#         -1 (the default value) means no limit.
#
#     Splitting starts at the front of the string and works to the end.
#
#     Note, str.split() is mainly useful for data that has been intentionally
#     delimited.  With natural text that includes punctuation, consider using
#     the regular expression module.
