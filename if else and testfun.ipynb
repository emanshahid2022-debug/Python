# %%
print ('want to hear a dirty joke')
age=10
if age==12:
   print ("A pig fell in the mud")
else:    
   print ("Sshh,it's a secret")
# Out:
# want to hear a dirty joke
# Sshh,it's a secret

# %%
age=15
if age<=10 :
    print(' I want to tell you a joke.')
elif age ==12:
    print('you are my bestie')
elif age ==11:
    print('I have 2 sisters')
elif age==14:
    print('I love my family')
else:
    print('Huh?')
# Out:
# Huh?

# %%
age = 14
if age == 10 or age == 11 or age == 12 or age == 13:
    print('12+13+78+19+1041+25+10 or a headache sum,I want a solution')
else:
    print('ahh,ahhhahiiihooo')
# Out:
# ahh,ahhhahiiihooo

# %%
list(range(0,5))
# Out:
# [0, 1, 2, 3, 4]

# %%
testfunc('mary')

def testfunc (myname):
     print('hello %s'% myname)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 testfunc('mary')
#       3 def testfunc (myname):
#       4      print('hello %s'% myname)
#
# NameError: name 'testfunc' is not defined
