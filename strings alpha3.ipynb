# %%
my_string="%i+%i=%i" % (3,6,9)
my_string
# Out:
# '3+6=9'

# %%
my_string="%i+%i=%i" % (5,7,12)
my_string
# Out:
# '5+7=12'

# %%
float_string= "%f" %(2.2777)
float_string
# Out:
# '2.277700'

# %%
float_string2= "%.2f" %(2.2777)
float_string2
# Out:
# '2.28'

# %%
float_string= "%f" %(2.26237412353)
float_string
# Out:
# '2.262374'

# %%
float_string= "%f" %(2.262374)
float_string
# Out:
# '2.262374'

# %%
float_string= "%f" %(2.26237414)
float_string
# Out:
# '2.262374'

# %%
float_string2= "%.7f" %(4.542781)
float_string2
# Out:
# '4.5427810'

# %%
float_string2= "%.7f" %(4.5427817876)
float_string2
# Out:
# '4.5427818'

# %%
float_string2= "%.15f" %(3.764812830912458237)
float_string2
# Out:
# '3.764812830912458'
